# %%
pip install openai
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 3.9 MB/s  0:00:00
# ...
#
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
# ...

# %%
from openai import OpenAI

client = OpenAI(
    api_key="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",
    base_url="https://api.groq.com/openai/v1"
)

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "user", "content": "Say hello"}
    ]
)
print(response.choices[0].message.content)
# Out:
# Hello. How can I help you today?

# %%
from openai import OpenAI

client = OpenAI(
    api_key="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",
    base_url="https://api.groq.com/openai/v1"
)

topic = input("Enter a topic to study: ")

prompt = f"""
You are an education assistant.

Explain the topic: {topic}

Provide:
1. Simple Explanation
2. Five Key Points
3. Three Quiz Questions
"""

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "user", "content": prompt}
    ]
)

print(response.choices[0].message.content)
